# %%
a = ['abc',0.87,True,'9487','QQ']
for i in a:
    print(i)
# Out:
# abc
# 0.87
# True
# 9487
# QQ

# %%
singers = ['justin bieber','taylor swift','lady gaga','katy parry']
singers.append('sia')
print(singers)

singers.insert(2,'britney spears')
print(singers)
# Out:
# ['justin bieber', 'taylor swift', 'lady gaga', 'katy parry', 'sia']
# ['justin bieber', 'taylor swift', 'britney spears', 'lady gaga', 'katy parry', 'sia']

# %%
import facebook
graph = facebook.GraphAPI(access_token='EAACEdEose0cBAAoihkYYnq8tJhAMoMu2DEkadxyEGZCNFaLTJUbO5ZCKihSKMo1JwP7OewypL3Duo6zOTfT0mZCUgcf9GgyAtMBGs6aqddIJ50S8slYxXOtl2N1rxnJkt6Dkt4ebyx4OyGO3pF1oS27PgETEupCvLrh9ByztYPlvGtAcDAvn5QKvE5RKo2ALogZACIkUMwZDZD',version= '2.7')

attachment = {
    'name':'Post Tesst',
    'caption':'Check out this example',
    'description':'This is a longer description of the attachment',
}

graph.put_wall_post(message='我是一個Graph API測試2，大推Python超好玩!',attachment = attachment)
# Out:
# {'id': '736824876404164_1631383300281646'}

# %%
from bs4 import BeautifulSoup
html_sample = '\
<html> \
    <body> \
    <h1 id ="title">Hello World</h1> \
    <a href="#" class="link">This is link1</a> \
    <a href="# link2" class="link">This is link2</a> \
    </body> \
</html>'


soup = BeautifulSoup(html_sample,"html5lib")
print(soup.select('h1'))
# Out:
# [<h1 id="title">Hello World</h1>]

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('https://s.taobao.com/search?q=%E9%A6%99%E6%B0%B4.%E7%94%B7%E5%A3%AB&imgfile=&ie=utf8')
soup = BeautifulSoup(res.text,"html5lib")
for item for soup.select('.J_MouserOnverReq'):
    print (item.select('strong')[0].text, item.select('.title')[0].text)
# Out:
#   File "<ipython-input-1-c50e83295457>", line 5
#     for item for soup.select('.J_MouserOnverReq'):
#                ^
# SyntaxError: invalid syntax

# %%
import requests
payload = {
    'startStation':'3301e395-46b8-47aa-aa37-139e15708779',
    'endStation':'977abb69-413a-4ccf-a109-0272c24fd490',
    'theDay':'2018/03/03',
    'timeSelect':'05:00',
    'waySelect':'DepartureInMandarin'
}
res = requests.post('https://m.thsrc.com.tw/tw/TimeTable/SearchResult', data = payload)
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-tw">
# <head><meta charset="utf-8" /><title>
# 	台灣高鐵 Taiwan High Speed Rail
# </title><meta name="keywords" content="高鐵,快速,旅遊假期,遊玩" /><meta name="description" content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。" />
#     <!-- Facebook -->
#     <meta property="og:description" content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。" /><meta property="og:image" content="http://www.thsrc.com.tw/Content/logo.jpg" />
#     <!--Google +1 start-->
#     <meta itemprop="name" content="台灣高鐵" /><meta itemprop="description" content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。" /><meta itemprop="image" content="http://www.thsrc.com.tw/Content/logo.jpg" />
#     <!-- ViewPort -->
# ...

# %%
import pandas as pd
cars = ["BMW","BENZ","Toyota","Nissan","Lexus"]

select = pd.Series(cars)
print(select)
# Out:
# 0       BMW
# 1      BENZ
# 2    Toyota
# 3    Nissan
# 4     Lexus
# dtype: object

# %%
import pandas as pd

dict = {
    "factory":"Taipei",
    "sensor1":"1",
    "sensor2":"2",
    "sensor3":"3",
    "sensor4":"4",
    "sensor5":"5",
}

select = pd.Series(dict, index = dict.keys())
print(select[0])
print("========")
print(select['sensor1':])
print("========")
print(select[[0,2,4]])
print("========")
print(select[['factory','sensor1','sensor3']])
# Out:
# Taipei
# ...
# sensor1    1
# sensor2    2
# sensor3    3
# sensor4    4
# sensor5    5
# dtype: object
# ...
# factory    Taipei
# sensor2         2
# sensor4         4
# dtype: object
# ...
# factory    Taipei
# sensor1         1
# sensor3         3
# dtype: object

# %%
import pandas as pd

groups= num  = [['Movies',46],['Sports',8],['Coding',12],['Flashing',12],['Dancing',6],['Cooking',58]]


select_df = pd.DataFrame(groups, columns = ["groups","num"])

print(select_df)
# Out:
#      groups  num
# 0    Movies   46
# 1    Sports    8
# 2    Coding   12
# 3  Flashing   12
# 4   Dancing    6
# 5   Cooking   58

# %%
import pandas as pd 
arr = groups = [["Movies",46],["Sports",8],["Coding",12],["Flashing",120],["Dancing",6],["Cooking",8]]
df = pd.DataFrame(arr, columns = ["name","num"])
print(df)
# Out:
#        name  num
# 0    Movies   46
# 1    Sports    8
# 2    Coding   12
# 3  Flashing  120
# 4   Dancing    6
# 5   Cooking    8

# %%
import pandas as pd

groups = ["Movies","Sports","Coding","Fishing","Dancing","Cooking"]
num = [46,8,12,12,6,58]

dict = {
    "groups":groups,
    "num":num
}

select_df = pd.DataFrame(dict)

print(select_df.shape) #回傳列數與欄數
print("---")
print(select_df.describe())  #回傳描述性統計
print("---")
print(select_df.head(3)) #回傳前三筆觀望值
print("---")
print(select_df.tail(3)) #回傳後三筆觀望值
print("---")
print(select_df.columns) #回傳欄位名稱
print("---")
print(select_df.index) #回傳index
print("---")
print(select_df.info) #回傳資料內容
print("---")
print(select_df.iloc[0,1]) #第一列第二欄:人數
print("---")
print(select_df.iloc[0:1,:]) #第一列:組的組名與組數
print("---")
print(select_df.iloc[:,1]) #第二欄:各組的人數
print("---")
print(select_df["num"]) #各組的人數
print("---")
print(select_df.num) #各組的人數
print("==========================")
out_df = select_df[select_df.loc[:,"num"]>10]
print(out_df)

print("============================")
select_df.sort_index(axis = 0,ascending = True) #透過索引值做排序，axis可以指定第幾行，ascending用於設定昇冪或降冪
# Out:
# (6, 2)
# ---
#              num
# count   6.000000
# mean   23.666667
# std    22.393451
# min     6.000000
# 25%     9.000000
# 50%    12.000000
# 75%    37.500000
# max    58.000000
# ---
#    groups  num
# 0  Movies   46
# 1  Sports    8
# 2  Coding   12
# ---
#     groups  num
# 3  Fishing   12
# 4  Dancing    6
# 5  Cooking   58
# ---
# Index(['groups', 'num'], dtype='object')
# ---
# RangeIndex(start=0, stop=6, step=1)
# ---
# <bound method DataFrame.info of     groups  num
# 0   Movies   46
# 1   Sports    8
# 2   Coding   12
# 3  Fishing   12
# 4  Dancing    6
# 5  Cooking   58>
# ---
# 46
# ---
#    groups  num
# 0  Movies   46
# ---
# 0    46
# 1     8
# 2    12
# 3    12
# 4     6
# 5    58
# Name: num, dtype: int64
# ---
# 0    46
# 1     8
# 2    12
# 3    12
# 4     6
# 5    58
# Name: num, dtype: int64
# ---
# 0    46
# 1     8
# 2    12
# 3    12
# 4     6
# 5    58
# Name: num, dtype: int64
# ...
#     groups  num
# 0   Movies   46
# 2   Coding   12
# 3  Fishing   12
# ...

# %%
import pandas as pd

groups = ["Movies","Sports","Coding","Fishing","Dancing","Cooking"]
num = [46,8,12,12,6,58]

dict = {
    "groups":groups,
    "num":num
}

select_df = pd.DataFrame(dict)

select_df.sort_values(by = 'num')
# Out:
#     groups  num
# 4  Dancing    6
# 1   Sports    8
# 2   Coding   12
# 3  Fishing   12
# 0   Movies   46
# 5  Cooking   58

# %%
import pandas as pd
df = pd.read_csv('shop_list2.csv')
print(df)

select_df = pd.DataFrame(df)

print(select_df.loc[:,"shop name"].isnull()) #判斷那些店名是遺失值
print("-----")
print(select_df.loc[:,"maket size"].notnull()) #判斷哪些市場規模不是遺失值
# Out:
#    shop id shop name  maket size
# 0        1  Wal mart   3000000.0
# 1        2    Costco   2000000.0
# 2        3       NaN   1500000.0
# 3        4    Pchome    300000.0
# 4        5     Yahoo         NaN
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: shop name, dtype: bool
# -----
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: maket size, dtype: bool

# %%
import pandas as pd
df = pd.read_csv('shop_list2.csv')
print(df)

select_df = pd.DataFrame(df)

drop_value = select_df.dropna() # 有遺失值的觀測值都刪除
print(drop_value)
print("-----")
filled_value = select_df.fillna(0)  # 有遺失值的觀測值填補 0 
print(filled_value)
print("-----")
filled_value_column = select_df.fillna({"shop name":"NULL","maket size":0}) # 依欄位填補遺失值 
print(filled_value_column)
# Out:
#    shop id shop name  maket size
# 0        1  Wal mart   3000000.0
# 1        2    Costco   2000000.0
# 2        3       NaN   1500000.0
# 3        4    Pchome    300000.0
# 4        5     Yahoo         NaN
#    shop id shop name  maket size
# 0        1  Wal mart   3000000.0
# 1        2    Costco   2000000.0
# 3        4    Pchome    300000.0
# -----
#    shop id shop name  maket size
# 0        1  Wal mart   3000000.0
# 1        2    Costco   2000000.0
# 2        3         0   1500000.0
# 3        4    Pchome    300000.0
# 4        5     Yahoo         0.0
# -----
#    shop id shop name  maket size
# 0        1  Wal mart   3000000.0
# 1        2    Costco   2000000.0
# 2        3      NULL   1500000.0
# 3        4    Pchome    300000.0
# 4        5     Yahoo         0.0
